# %%
import pandas as pd
import numpy as np
from pathlib import Path

# Import Recommenders library
import recommenders as rec

# %%
ROOT = Path.cwd().parent
games = pd.read_csv(ROOT / "data" / "GRS" / "games.csv")
recs = pd.read_csv(ROOT / "data" / "GRS" / "recommendations.csv")
users = pd.read_csv(ROOT / "data" / "GRS" / "users.csv")

# %%
# users.head()
users.shape
# Out:
#     user_id  products  reviews
# 0   7360263       359        0
# 1  14020781       156        1
# 2   8762579       329        4
# 3   4820647       176        4
# 4   5167327        98        2

# %%
# games.head()
games.shape
# Out:
# (50872, 13)

# %%
# recs.head()
recs.shape
# Out:
# (41154794, 8)

# %%
names = ["count", "mean", "std", "min", "25%", "50%", "75%", "max"]

for col in tmp.columns:
    print(f"\n{col}:")
    for l, v in zip(names, tmp[col]):
        print(f"{l}\t{round(v, 2)}")
    print()
